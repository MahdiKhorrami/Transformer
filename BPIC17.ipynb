# %%
# !pip install wget
# !pip install pm4py
# !pip install processtransformer==0.1.3
# Out:
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py): started
#   Building wheel for wget (setup.py): finished with status 'done'
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9657 sha256=59b2751ec514f96d9792a0597863e4b8b7a1b925dfcf99c0928b02f8246e16fa
#   Stored in directory: c:\users\mahdi\appdata\local\pip\cache\wheels\04\5f\3e\46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2
# Requirement already satisfied: pm4py in c:\users\mahdi\anaconda3\lib\site-packages (2.3.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\mahdi\anaconda3\lib\site-packages (from pm4py) (1.23.5)
# Requirement already satisfied: sympy in c:\users\mahdi\anaconda3\lib\site-packages (from pm4py) (1.10.1)
# Requirement already satisfied: deprecation in c:\users\mahdi\anaconda3\lib\site-packages (from pm4py) (2.1.0)
# Requirement already satisfied: stringdist in c:\users\mahdi\anaconda3\lib\site-packages (from pm4py) (1.0.9)
# Requirement already satisfied: lxml in c:\users\mahdi\anaconda3\lib\site-packages (from pm4py) (4.9.1)
# Requirement already satisfied: pandas>=1.1.5 in c:\users\mahdi\anaconda3\lib\site-packages (from pm4py) (1.4.4)
# Requirement already satisfied: scipy in c:\users\mahdi\anaconda3\lib\site-packages (from pm4py) (1.9.1)
# Requirement already satisfied: networkx in c:\users\mahdi\anaconda3\lib\site-packages (from pm4py) (2.8.4)
# Requirement already satisfied: pydotplus in c:\users\mahdi\anaconda3\lib\site-packages (from pm4py) (2.0.2)
# Requirement already satisfied: pytz in c:\users\mahdi\anaconda3\lib\site-packages (from pm4py) (2022.1)
# Requirement already satisfied: cvxopt in c:\users\mahdi\anaconda3\lib\site-packages (from pm4py) (1.3.0)
# Requirement already satisfied: tqdm in c:\users\mahdi\anaconda3\lib\site-packages (from pm4py) (4.64.1)
# Requirement already satisfied: graphviz in c:\users\mahdi\anaconda3\lib\site-packages (from pm4py) (0.20.1)
# Requirement already satisfied: matplotlib in c:\users\mahdi\anaconda3\lib\site-packages (from pm4py) (3.5.2)
# Requirement already satisfied: intervaltree in c:\users\mahdi\anaconda3\lib\site-packages (from pm4py) (3.1.0)
# Requirement already satisfied: pyvis in c:\users\mahdi\anaconda3\lib\site-packages (from pm4py) (0.3.1)
# Requirement already satisfied: jsonpickle in c:\users\mahdi\anaconda3\lib\site-packages (from pm4py) (3.0.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\mahdi\anaconda3\lib\site-packages (from pandas>=1.1.5->pm4py) (2.8.2)
# Requirement already satisfied: packaging in c:\users\mahdi\anaconda3\lib\site-packages (from deprecation->pm4py) (21.3)
# Requirement already satisfied: sortedcontainers<3.0,>=2.0 in c:\users\mahdi\anaconda3\lib\site-packages (from intervaltree->pm4py) (2.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\mahdi\anaconda3\lib\site-packages (from matplotlib->pm4py) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mahdi\anaconda3\lib\site-packages (from matplotlib->pm4py) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mahdi\anaconda3\lib\site-packages (from matplotlib->pm4py) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\mahdi\anaconda3\lib\site-packages (from matplotlib->pm4py) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mahdi\anaconda3\lib\site-packages (from matplotlib->pm4py) (9.2.0)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\mahdi\anaconda3\lib\site-packages (from pyvis->pm4py) (7.31.1)
# Requirement already satisfied: jinja2>=2.9.6 in c:\users\mahdi\anaconda3\lib\site-packages (from pyvis->pm4py) (3.1.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\mahdi\anaconda3\lib\site-packages (from sympy->pm4py) (1.2.1)
# Requirement already satisfied: colorama in c:\users\mahdi\anaconda3\lib\site-packages (from tqdm->pm4py) (0.4.5)
# Requirement already satisfied: pickleshare in c:\users\mahdi\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis->pm4py) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\mahdi\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis->pm4py) (0.18.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\mahdi\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis->pm4py) (63.4.1)
# Requirement already satisfied: traitlets>=4.2 in c:\users\mahdi\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis->pm4py) (5.1.1)
# Requirement already satisfied: pygments in c:\users\mahdi\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis->pm4py) (2.11.2)
# Requirement already satisfied: decorator in c:\users\mahdi\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis->pm4py) (5.1.1)
# Requirement already satisfied: matplotlib-inline in c:\users\mahdi\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis->pm4py) (0.1.6)
# Requirement already satisfied: backcall in c:\users\mahdi\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis->pm4py) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\mahdi\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis->pm4py) (3.0.20)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mahdi\anaconda3\lib\site-packages (from jinja2>=2.9.6->pyvis->pm4py) (2.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\mahdi\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->pm4py) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\mahdi\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis->pm4py) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\mahdi\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis->pm4py) (0.2.5)
# Requirement already satisfied: processtransformer==0.1.3 in c:\users\mahdi\anaconda3\lib\site-packages (0.1.3)
# Requirement already satisfied: tensorflow>=2.4 in c:\users\mahdi\anaconda3\lib\site-packages (from processtransformer==0.1.3) (2.12.0)
# Requirement already satisfied: scikit-learn in c:\users\mahdi\anaconda3\lib\site-packages (from processtransformer==0.1.3) (1.0.2)
# Requirement already satisfied: numpy in c:\users\mahdi\anaconda3\lib\site-packages (from processtransformer==0.1.3) (1.23.5)
# Requirement already satisfied: pandas in c:\users\mahdi\anaconda3\lib\site-packages (from processtransformer==0.1.3) (1.4.4)
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\mahdi\anaconda3\lib\site-packages (from tensorflow>=2.4->processtransformer==0.1.3) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\mahdi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (16.0.0)
# Requirement already satisfied: packaging in c:\users\mahdi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (21.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\mahdi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (1.55.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\mahdi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (2.3.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\mahdi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (2.12.3)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\mahdi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (0.2.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\mahdi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (2.12.0)
# Requirement already satisfied: setuptools in c:\users\mahdi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (63.4.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\mahdi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (1.14.1)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\mahdi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (2.12.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\mahdi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (4.21.12)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\mahdi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (0.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\mahdi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (4.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\mahdi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (1.4.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\mahdi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (1.16.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\mahdi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (0.4.10)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\mahdi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (0.31.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\mahdi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (3.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\mahdi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (1.6.3)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\mahdi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (3.7.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\mahdi\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (23.5.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mahdi\anaconda3\lib\site-packages (from pandas->processtransformer==0.1.3) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\mahdi\anaconda3\lib\site-packages (from pandas->processtransformer==0.1.3) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mahdi\anaconda3\lib\site-packages (from scikit-learn->processtransformer==0.1.3) (2.2.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\mahdi\anaconda3\lib\site-packages (from scikit-learn->processtransformer==0.1.3) (1.9.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\mahdi\anaconda3\lib\site-packages (from scikit-learn->processtransformer==0.1.3) (1.1.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\mahdi\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (0.37.1)
# Requirement already satisfied: ml-dtypes>=0.1.0 in c:\users\mahdi\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (0.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\mahdi\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (0.7.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\mahdi\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (1.0.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\mahdi\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (2.2.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\mahdi\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (2.18.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\mahdi\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (2.28.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\mahdi\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (3.3.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\mahdi\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (3.0.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\mahdi\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\mahdi\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\mahdi\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (5.3.0)
# Requirement already satisfied: urllib3<2.0 in c:\users\mahdi\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (1.26.11)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\mahdi\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mahdi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\mahdi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mahdi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\mahdi\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\mahdi\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\mahdi\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=2.4->processtransformer==0.1.3) (3.2.2)

# %%
import os
import wget
import argparse
import pm4py
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn import metrics 

from processtransformer import constants
from processtransformer.models import transformer
from processtransformer.data.loader import LogsDataLoader
from processtransformer.data.processor import LogsDataProcessor

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data_dir = "./datasets/"
if not os.path.exists(data_dir): 
  os.mkdir(data_dir)
_ = wget.download("https://data.4tu.nl/file/34c3f44b-3101-4ea9-8281-e38905c68b8d/f3aec4f7-d52c-4217-82f4-57d719a8298c")


input_file_path= wget.download("https://data.4tu.nl/file/34c3f44b-3101-4ea9-8281-e38905c68b8d/f3aec4f7-d52c-4217-82f4-57d719a8298c")
output_file_path='./datasets/BPIC17.csv'

#Write to Pandas Dataframe
log = pm4py.read_xes(input_file_path) #Input Filename
df = pm4py.convert_to_dataframe(log)
df.to_csv(output_file_path)
# Out:
# parsing log, completed traces ::   0%|          | 0/31509 [00:00<?, ?it/s]

# %%
data_processor = LogsDataProcessor(name='BPIC17', filepath="datasets/BPIC17.csv",  
                                    columns = ["case:concept:name", "concept:name", "time:timestamp"], #specify the columns name containing case_id, activity name and timestamp 
                                    dir_path='datasets', pool = 4)
data_processor.process_logs(task=constants.Task.NEXT_ACTIVITY, sort_temporally= False)

# %%
# Load data
data_loader = LogsDataLoader(name = 'BPIC17')

(train_df, test_df, x_word_dict, y_word_dict, max_case_length, 
    vocab_size, num_output) = data_loader.load_data(constants.Task.NEXT_ACTIVITY)

# Prepare training examples for next activity prediction task
train_token_x, train_token_y = data_loader.prepare_data_next_activity(train_df, 
    x_word_dict, y_word_dict, max_case_length)

# %%
learning_rate = 0.001
batch_size = 12
epochs = 10

# %%
# Create and train a transformer model
transformer_model = transformer.get_next_activity_model(
    max_case_length=max_case_length, 
    vocab_size=vocab_size,
    output_dim=num_output)

transformer_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])

transformer_model.fit(train_token_x, train_token_y, 
    epochs=epochs, batch_size=batch_size)
# Out:
# Epoch 1/10
# 78000/78000 [==============================] - 5445s 70ms/step - loss: 0.4530 - sparse_categorical_accuracy: 0.8471
# Epoch 2/10
# 78000/78000 [==============================] - 5442s 70ms/step - loss: 0.3707 - sparse_categorical_accuracy: 0.8697
# Epoch 3/10
# 78000/78000 [==============================] - 5425s 70ms/step - loss: 0.3634 - sparse_categorical_accuracy: 0.8705
# Epoch 4/10
# 78000/78000 [==============================] - 5639s 72ms/step - loss: 0.3594 - sparse_categorical_accuracy: 0.8713
# Epoch 5/10
# 78000/78000 [==============================] - 6683s 86ms/step - loss: 0.3571 - sparse_categorical_accuracy: 0.8716
# Epoch 6/10
# 78000/78000 [==============================] - 8154s 105ms/step - loss: 0.3566 - sparse_categorical_accuracy: 0.8716
# Epoch 7/10
# 78000/78000 [==============================] - 7717s 99ms/step - loss: 0.3559 - sparse_categorical_accuracy: 0.8719
# Epoch 8/10
# 78000/78000 [==============================] - 7036s 90ms/step - loss: 0.3557 - sparse_categorical_accuracy: 0.8720
# Epoch 9/10
# 78000/78000 [==============================] - 7108s 91ms/step - loss: 0.3559 - sparse_categorical_accuracy: 0.8721
# Epoch 10/10
# 78000/78000 [==============================] - 6689s 86ms/step - loss: 0.3561 - sparse_categorical_accuracy: 0.8721

# %%
# Evaluate over all the prefixes (k) and save the results
k, accuracies,fscores, precisions, recalls = [],[],[],[],[]
for i in range(max_case_length):
    test_data_subset = test_df[test_df["k"]==i]
    if len(test_data_subset) > 0:
        test_token_x, test_token_y = data_loader.prepare_data_next_activity(test_data_subset, 
            x_word_dict, y_word_dict, max_case_length)   
        y_pred = np.argmax(transformer_model.predict(test_token_x), axis=1)
        accuracy = metrics.accuracy_score(test_token_y, y_pred)
        precision, recall, fscore, _ = metrics.precision_recall_fscore_support(
            test_token_y, y_pred, average="weighted")
        k.append(i)
        accuracies.append(accuracy)
        fscores.append(fscore)
        precisions.append(precision)
        recalls.append(recall)

k.append(i + 1)
accuracies.append(np.mean(accuracy))
fscores.append(np.mean(fscores))
precisions.append(np.mean(precisions))
recalls.append(np.mean(recalls))
# Out:
# 197/197 [==============================] - 21s 98ms/step
# 197/197 [==============================] - 19s 95ms/step
# 197/197 [==============================] - 20s 100ms/step
# 197/197 [==============================] - 19s 94ms/step
# 197/197 [==============================] - 19s 96ms/step
# 197/197 [==============================] - 19s 96ms/step
# 197/197 [==============================] - 19s 97ms/step
# 197/197 [==============================] - 20s 99ms/step
# 197/197 [==============================] - 19s 97ms/step
# 197/197 [==============================] - 20s 99ms/step
# 197/197 [==============================] - 19s 96ms/step
# 197/197 [==============================] - 20s 101ms/step
# 197/197 [==============================] - 19s 98ms/step
# 197/197 [==============================] - 19s 98ms/step
# 197/197 [==============================] - 19s 96ms/step
# 196/196 [==============================] - 20s 100ms/step
# 196/196 [==============================] - 19s 97ms/step
# 188/188 [==============================] - 18s 98ms/step
# 186/186 [==============================] - 18s 97ms/step
# 183/183 [==============================] - 18s 96ms/step
# 174/174 [==============================] - 17s 98ms/step
# 166/166 [==============================] - 16s 96ms/step
# 161/161 [==============================] - 16s 97ms/step
# 152/152 [==============================] - 15s 96ms/step
# 146/146 [==============================] - 14s 96ms/step
# 139/139 [==============================] - 14s 97ms/step
# 133/133 [==============================] - 13s 94ms/step
# 126/126 [==============================] - 12s 97ms/step
# 122/122 [==============================] - 12s 98ms/step
# 117/117 [==============================] - 11s 96ms/step
# 112/112 [==============================] - 11s 96ms/step
# 107/107 [==============================] - 10s 98ms/step
# 103/103 [==============================] - 10s 94ms/step
# 99/99 [==============================] - 9s 94ms/step
# 94/94 [==============================] - 9s 96ms/step
# 90/90 [==============================] - 9s 94ms/step
# 86/86 [==============================] - 9s 99ms/step
# 82/82 [==============================] - 8s 94ms/step
# 77/77 [==============================] - 7s 92ms/step
# 73/73 [==============================] - 7s 93ms/step
# 69/69 [==============================] - 7s 95ms/step
# 65/65 [==============================] - 6s 96ms/step
# 61/61 [==============================] - 6s 98ms/step
# 58/58 [==============================] - 5s 93ms/step
# 55/55 [==============================] - 5s 92ms/step
# 52/52 [==============================] - 5s 93ms/step
# 48/48 [==============================] - 5s 96ms/step
# 46/46 [==============================] - 4s 96ms/step
# 43/43 [==============================] - 4s 95ms/step
# 41/41 [==============================] - 4s 100ms/step
# 38/38 [==============================] - 4s 97ms/step
# 36/36 [==============================] - 3s 91ms/step
# 34/34 [==============================] - 3s 91ms/step
# 32/32 [==============================] - 3s 93ms/step
# 29/29 [==============================] - 3s 93ms/step
# 27/27 [==============================] - 3s 92ms/step
# 26/26 [==============================] - 2s 91ms/step
# 24/24 [==============================] - 2s 97ms/step
# 23/23 [==============================] - 2s 92ms/step
# 21/21 [==============================] - 2s 92ms/step
# 20/20 [==============================] - 2s 94ms/step
# 18/18 [==============================] - 2s 95ms/step
# 17/17 [==============================] - 2s 95ms/step
# 16/16 [==============================] - 2s 94ms/step
# 15/15 [==============================] - 1s 97ms/step
# 14/14 [==============================] - 1s 102ms/step
# 14/14 [==============================] - 1s 93ms/step
# 13/13 [==============================] - 1s 90ms/step
# 11/11 [==============================] - 1s 96ms/step
# 11/11 [==============================] - 1s 84ms/step
# 10/10 [==============================] - 1s 91ms/step
# 9/9 [==============================] - 1s 92ms/step
# 9/9 [==============================] - 1s 85ms/step
# 8/8 [==============================] - 1s 91ms/step
# 7/7 [==============================] - 1s 94ms/step
# 7/7 [==============================] - 1s 88ms/step
# 6/6 [==============================] - 1s 91ms/step
# 6/6 [==============================] - 1s 80ms/step
# 5/5 [==============================] - 0s 85ms/step
# 5/5 [==============================] - 0s 83ms/step
# 5/5 [==============================] - 0s 73ms/step
# 4/4 [==============================] - 0s 90ms/step
# 4/4 [==============================] - 0s 82ms/step
# 4/4 [==============================] - 0s 75ms/step
# 4/4 [==============================] - 0s 73ms/step
# 3/3 [==============================] - 0s 95ms/step
# 3/3 [==============================] - 0s 85ms/step
# 3/3 [==============================] - 0s 72ms/step
# 3/3 [==============================] - 0s 58ms/step
# 3/3 [==============================] - 0s 52ms/step
# 3/3 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 55ms/step

# %%
print('Average accuracy across all prefixes:', np.mean(accuracies))
print('Average f-score across all prefixes:', np.mean(fscores))
print('Average precision across all prefixes:', np.mean(precisions))
print('Average recall across all prefixes:', np.mean(recalls))
# Out:
# Average accuracy across all prefixes: 0.8426708183994187
# Average f-score across all prefixes: 0.8174516907598661
# Average precision across all prefixes: 0.810716546424318
# Average recall across all prefixes: 0.841607783388604

# %%
data_processor = LogsDataProcessor(name='BPIC17', filepath="datasets/BPIC17.csv",  
                                    columns = ["case:concept:name", "concept:name", "time:timestamp"],  #specify the columns name containing case_id, activity name and timestamp 
                                    dir_path='datasets', pool = 4)
data_processor.process_logs(task=constants.Task.NEXT_TIME, sort_temporally= False)

# %%
# Load data
data_loader = LogsDataLoader(name = 'BPIC17')

(train_df, test_df, x_word_dict, y_word_dict, max_case_length, 
    vocab_size, num_output) = data_loader.load_data(constants.Task.NEXT_TIME)

# Prepare training examples for next time prediction task
(train_token_x, train_time_x, train_token_y, time_scaler, y_scaler) = \
                                    data_loader.prepare_data_next_time(train_df, x_word_dict, max_case_length)

# %%
learning_rate = 0.001
batch_size = 12
epochs = 1

# %%
# Create and train a transformer model
transformer_model = transformer.get_next_time_model(
        max_case_length=max_case_length, 
        vocab_size=vocab_size)

transformer_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate),
        loss=tf.keras.losses.LogCosh())

transformer_model.fit([train_token_x, train_time_x], train_token_y, 
        epochs=epochs, batch_size=batch_size, verbose=2)
# Out:
# 80101/80101 - 8046s - loss: 0.1079 - 8046s/epoch - 100ms/step

# %%
# Evaluate over all the prefixes (k) and save the results
k, maes, mses, rmses = [],[],[],[]
for i in range(max_case_length):
    test_data_subset = test_df[test_df["k"]==i]
    if len(test_data_subset) > 0:
        test_token_x, test_time_x, test_y, _, _ = data_loader.prepare_data_next_time(
            test_data_subset, x_word_dict, max_case_length, time_scaler, y_scaler, False)   

        y_pred = transformer_model.predict([test_token_x, test_time_x])
        _test_y = y_scaler.inverse_transform(test_y)
        _y_pred = y_scaler.inverse_transform(y_pred)

        k.append(i)
        maes.append(metrics.mean_absolute_error(_test_y, _y_pred))
        mses.append(metrics.mean_squared_error(_test_y, _y_pred))
        rmses.append(np.sqrt(metrics.mean_squared_error(_test_y, _y_pred)))

k.append(i + 1)
maes.append(np.mean(maes))
mses.append(np.mean(mses))
rmses.append(np.mean(rmses))
# Out:
# 197/197 [==============================] - 24s 118ms/step
# 197/197 [==============================] - 23s 119ms/step
# 197/197 [==============================] - 23s 116ms/step
# 197/197 [==============================] - 23s 118ms/step
# 197/197 [==============================] - 24s 120ms/step
# 197/197 [==============================] - 23s 117ms/step
# 197/197 [==============================] - 23s 115ms/step
# 197/197 [==============================] - 24s 121ms/step
# 197/197 [==============================] - 23s 119ms/step
# 197/197 [==============================] - 24s 119ms/step
# 197/197 [==============================] - 24s 120ms/step
# 197/197 [==============================] - 23s 118ms/step
# 197/197 [==============================] - 23s 118ms/step
# 197/197 [==============================] - 24s 124ms/step
# 197/197 [==============================] - 23s 116ms/step
# 197/197 [==============================] - 24s 119ms/step
# 196/196 [==============================] - 23s 118ms/step
# 196/196 [==============================] - 24s 120ms/step
# 188/188 [==============================] - 23s 123ms/step
# 186/186 [==============================] - 23s 124ms/step
# 183/183 [==============================] - 22s 122ms/step
# 174/174 [==============================] - 22s 124ms/step
# 166/166 [==============================] - 20s 118ms/step
# 161/161 [==============================] - 22s 134ms/step
# 152/152 [==============================] - 25s 160ms/step
# 146/146 [==============================] - 22s 150ms/step
# 139/139 [==============================] - 18s 126ms/step
# 133/133 [==============================] - 14s 105ms/step
# 126/126 [==============================] - 13s 101ms/step
# 122/122 [==============================] - 13s 103ms/step
# 117/117 [==============================] - 12s 104ms/step
# 112/112 [==============================] - 11s 101ms/step
# 107/107 [==============================] - 11s 107ms/step
# 103/103 [==============================] - 10s 100ms/step
# 99/99 [==============================] - 11s 106ms/step
# 94/94 [==============================] - 9s 96ms/step
# 90/90 [==============================] - 9s 99ms/step
# 86/86 [==============================] - 8s 93ms/step
# 82/82 [==============================] - 8s 97ms/step
# 77/77 [==============================] - 7s 91ms/step
# 73/73 [==============================] - 7s 97ms/step
# 69/69 [==============================] - 6s 91ms/step
# 65/65 [==============================] - 6s 97ms/step
# 61/61 [==============================] - 6s 93ms/step
# 58/58 [==============================] - 5s 94ms/step
# 55/55 [==============================] - 5s 96ms/step
# 52/52 [==============================] - 5s 94ms/step
# 48/48 [==============================] - 5s 95ms/step
# 46/46 [==============================] - 4s 96ms/step
# 43/43 [==============================] - 4s 94ms/step
# 41/41 [==============================] - 3s 84ms/step
# 38/38 [==============================] - 4s 92ms/step
# 36/36 [==============================] - 3s 92ms/step
# 34/34 [==============================] - 3s 92ms/step
# 32/32 [==============================] - 3s 90ms/step
# 29/29 [==============================] - 2s 84ms/step
# 27/27 [==============================] - 3s 92ms/step
# 26/26 [==============================] - 2s 92ms/step
# 24/24 [==============================] - 2s 94ms/step
# 23/23 [==============================] - 2s 91ms/step
# 21/21 [==============================] - 2s 90ms/step
# 20/20 [==============================] - 2s 86ms/step
# 18/18 [==============================] - 2s 89ms/step
# 17/17 [==============================] - 2s 102ms/step
# 16/16 [==============================] - 2s 97ms/step
# 15/15 [==============================] - 1s 91ms/step
# 14/14 [==============================] - 1s 90ms/step
# 14/14 [==============================] - 1s 86ms/step
# 13/13 [==============================] - 1s 84ms/step
# 11/11 [==============================] - 1s 93ms/step
# 11/11 [==============================] - 1s 87ms/step
# 10/10 [==============================] - 1s 91ms/step
# 9/9 [==============================] - 1s 96ms/step
# 9/9 [==============================] - 1s 75ms/step
# 8/8 [==============================] - 1s 84ms/step
# 7/7 [==============================] - 1s 88ms/step
# 7/7 [==============================] - 1s 75ms/step
# 6/6 [==============================] - 1s 99ms/step
# 6/6 [==============================] - 1s 79ms/step
# 5/5 [==============================] - 0s 87ms/step
# 5/5 [==============================] - 0s 81ms/step
# 5/5 [==============================] - 0s 70ms/step
# 4/4 [==============================] - 0s 87ms/step
# 4/4 [==============================] - 0s 82ms/step
# 4/4 [==============================] - 0s 76ms/step
# 4/4 [==============================] - 0s 67ms/step
# 3/3 [==============================] - 0s 86ms/step
# 3/3 [==============================] - 0s 79ms/step
# 3/3 [==============================] - 0s 65ms/step
# 3/3 [==============================] - 0s 60ms/step
# 3/3 [==============================] - 0s 58ms/step
# 3/3 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step

# %%
print('Average MAE across all prefixes:', np.mean(maes))
print('Average MSE across all prefixes:', np.mean(mses))
print('Average RMSE across all prefixes:', np.mean(rmses))
# Out:
# Average MAE across all prefixes: 0.3276172
# Average MSE across all prefixes: 2.1393125
# Average RMSE across all prefixes: 1.1289705

# %%
data_processor = LogsDataProcessor(name='BPIC17', filepath="datasets/BPIC17.csv",  
                                    columns = ["case:concept:name", "concept:name", "time:timestamp"],  #specify the columns name containing case_id, activity name and timestamp 
                                    dir_path='datasets', pool = 4)
data_processor.process_logs(task=constants.Task.REMAINING_TIME, sort_temporally= False)

# %%
# Load data
data_loader = LogsDataLoader(name = 'BPIC17')

(train_df, test_df, x_word_dict, y_word_dict, max_case_length, 
    vocab_size, num_output) = data_loader.load_data(constants.Task.REMAINING_TIME)

# Prepare training examples for next time prediction task
(train_token_x, train_time_x, 
    train_token_y, time_scaler, y_scaler) = data_loader.prepare_data_remaining_time(train_df, 
    x_word_dict, max_case_length)

# %%
learning_rate = 0.001
batch_size = 12
epochs = 1

# %%
# Create and train a transformer model
transformer_model = transformer.get_remaining_time_model(
    max_case_length=max_case_length, 
    vocab_size=vocab_size)

transformer_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate),
    loss=tf.keras.losses.LogCosh())

transformer_model.fit([train_token_x, train_time_x], train_token_y, 
        epochs=epochs, batch_size=batch_size, verbose=2)
# Out:
# 80101/80101 - 7172s - loss: 0.2254 - 7172s/epoch - 90ms/step

# %%
# Evaluate over all the prefixes (k) and save the results
k, maes, mses, rmses = [],[],[],[]
for i in range(max_case_length):
    test_data_subset = test_df[test_df["k"]==i]
    if len(test_data_subset) > 0:
        test_token_x, test_time_x, test_y, _, _ = data_loader.prepare_data_remaining_time(
            test_data_subset, x_word_dict, max_case_length, time_scaler, y_scaler, False)   

        y_pred = transformer_model.predict([test_token_x, test_time_x])
        _test_y = y_scaler.inverse_transform(test_y)
        _y_pred = y_scaler.inverse_transform(y_pred)

        k.append(i)
        maes.append(metrics.mean_absolute_error(_test_y, _y_pred))
        mses.append(metrics.mean_squared_error(_test_y, _y_pred))
        rmses.append(np.sqrt(metrics.mean_squared_error(_test_y, _y_pred)))

k.append(i + 1)
maes.append(np.mean(maes))
mses.append(np.mean(mses))
rmses.append(np.mean(rmses))
# Out:
# 197/197 [==============================] - 19s 95ms/step
# 197/197 [==============================] - 19s 94ms/step
# 197/197 [==============================] - 19s 94ms/step
# 197/197 [==============================] - 18s 93ms/step
# 197/197 [==============================] - 18s 93ms/step
# 197/197 [==============================] - 18s 94ms/step
# 197/197 [==============================] - 19s 95ms/step
# 197/197 [==============================] - 19s 94ms/step
# 197/197 [==============================] - 19s 94ms/step
# 197/197 [==============================] - 18s 93ms/step
# 197/197 [==============================] - 19s 94ms/step
# 197/197 [==============================] - 18s 93ms/step
# 197/197 [==============================] - 19s 95ms/step
# 197/197 [==============================] - 19s 94ms/step
# 197/197 [==============================] - 18s 94ms/step
# 197/197 [==============================] - 18s 93ms/step
# 196/196 [==============================] - 18s 93ms/step
# 196/196 [==============================] - 18s 93ms/step
# 188/188 [==============================] - 17s 93ms/step
# 186/186 [==============================] - 18s 94ms/step
# 183/183 [==============================] - 17s 93ms/step
# 174/174 [==============================] - 16s 94ms/step
# 166/166 [==============================] - 16s 93ms/step
# 161/161 [==============================] - 15s 93ms/step
# 152/152 [==============================] - 14s 93ms/step
# 146/146 [==============================] - 13s 92ms/step
# 139/139 [==============================] - 13s 93ms/step
# 133/133 [==============================] - 13s 94ms/step
# 126/126 [==============================] - 12s 93ms/step
# 122/122 [==============================] - 11s 91ms/step
# 117/117 [==============================] - 11s 93ms/step
# 112/112 [==============================] - 11s 94ms/step
# 107/107 [==============================] - 10s 91ms/step
# 103/103 [==============================] - 10s 94ms/step
# 99/99 [==============================] - 9s 92ms/step
# 94/94 [==============================] - 9s 91ms/step
# 90/90 [==============================] - 8s 94ms/step
# 86/86 [==============================] - 8s 90ms/step
# 82/82 [==============================] - 8s 94ms/step
# 77/77 [==============================] - 7s 90ms/step
# 73/73 [==============================] - 7s 91ms/step
# 69/69 [==============================] - 6s 92ms/step
# 65/65 [==============================] - 6s 88ms/step
# 61/61 [==============================] - 6s 96ms/step
# 58/58 [==============================] - 5s 91ms/step
# 55/55 [==============================] - 5s 89ms/step
# 52/52 [==============================] - 5s 95ms/step
# 48/48 [==============================] - 4s 93ms/step
# 46/46 [==============================] - 4s 86ms/step
# 43/43 [==============================] - 4s 95ms/step
# 41/41 [==============================] - 4s 97ms/step
# 38/38 [==============================] - 3s 90ms/step
# 36/36 [==============================] - 3s 87ms/step
# 34/34 [==============================] - 3s 91ms/step
# 32/32 [==============================] - 3s 94ms/step
# 29/29 [==============================] - 3s 97ms/step
# 27/27 [==============================] - 3s 92ms/step
# 26/26 [==============================] - 2s 88ms/step
# 24/24 [==============================] - 2s 86ms/step
# 23/23 [==============================] - 2s 90ms/step
# 21/21 [==============================] - 2s 97ms/step
# 20/20 [==============================] - 2s 93ms/step
# 18/18 [==============================] - 2s 97ms/step
# 17/17 [==============================] - 2s 96ms/step
# 16/16 [==============================] - 1s 88ms/step
# 15/15 [==============================] - 1s 87ms/step
# 14/14 [==============================] - 1s 88ms/step
# 14/14 [==============================] - 1s 83ms/step
# 13/13 [==============================] - 1s 84ms/step
# 11/11 [==============================] - 1s 97ms/step
# 11/11 [==============================] - 1s 88ms/step
# 10/10 [==============================] - 1s 93ms/step
# 9/9 [==============================] - 1s 95ms/step
# 9/9 [==============================] - 1s 85ms/step
# 8/8 [==============================] - 1s 96ms/step
# 7/7 [==============================] - 1s 106ms/step
# 7/7 [==============================] - 1s 88ms/step
# 6/6 [==============================] - 1s 92ms/step
# 6/6 [==============================] - 1s 86ms/step
# 5/5 [==============================] - 0s 82ms/step
# 5/5 [==============================] - 0s 78ms/step
# 5/5 [==============================] - 0s 72ms/step
# 4/4 [==============================] - 0s 83ms/step
# 4/4 [==============================] - 0s 76ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 63ms/step
# 3/3 [==============================] - 0s 78ms/step
# 3/3 [==============================] - 0s 72ms/step
# 3/3 [==============================] - 0s 68ms/step
# 3/3 [==============================] - 0s 58ms/step
# 3/3 [==============================] - 0s 50ms/step
# 3/3 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 72ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step

# %%
print('Average MAE across all prefixes:', np.mean(maes))
print('Average MSE across all prefixes:', np.mean(mses))
print('Average RMSE across all prefixes:', np.mean(rmses))
# Out:
# Average MAE across all prefixes: 5.2377768
# Average MSE across all prefixes: 54.289852
# Average RMSE across all prefixes: 7.0011034
